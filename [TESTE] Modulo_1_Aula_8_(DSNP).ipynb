# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Silva-R/data_science_projects/blob/main/%5BTESTE%5D%20Modulo_1_Aula_8_(DSNP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Exercício 1

# %%
#a
import pandas as pd

#b
path = 'https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/ocorrencias_aviacao.csv'
df = pd.read_csv(path)

#c
df.shape
# Out:
# (5208, 22)

# %%
#d
df.head()
# Out:
#    codigo_ocorrencia ocorrencia_classificacao  \
# 0    201305055424986                 ACIDENTE
# 1    201605160250139          INCIDENTE GRAVE
# 2    201805021421302                INCIDENTE
# 3    201311259977425          INCIDENTE GRAVE
# 4    201103187273112                INCIDENTE
#
#                                      ocorrencia_tipo  \
# 0                              FALHA DO MOTOR EM VOO
# 1  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 2                                          AERÓDROMO
# 3                                     POUSO SEM TREM
# 4                                             OUTROS
#
#                            ocorrencia_tipo_categoria ocorrencia_tipo_icao  \
# 0                FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 1  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO                 CTOL
# 2                                          AERÓDROMO                 ADRM
# ...

# %%
#e
df.dtypes
# Out:
# codigo_ocorrencia                   int64
# ocorrencia_classificacao           object
# ocorrencia_tipo                    object
# ocorrencia_tipo_categoria          object
# ocorrencia_tipo_icao               object
# ocorrencia_latitude               float64
# ocorrencia_longitude              float64
# ocorrencia_cidade                  object
# ocorrencia_uf                      object
# ocorrencia_pais                    object
# ocorrencia_aerodromo               object
# ocorrencia_dia                     object
# ocorrencia_horario                 object
# investigacao_aeronave_liberada     object
# investigacao_status                object
# divulgacao_relatorio_numero        object
# divulgacao_relatorio_publicado     object
# divulgacao_dia_publicacao          object
# total_recomendacoes                 int64
# total_aeronaves_envolvidas          int64
# ocorrencia_saida_pista             object
# ocorrencia_dia_extracao            object
# dtype: object

# %%
#f
df.head(3)
# Out:
#    codigo_ocorrencia ocorrencia_classificacao  \
# 0    201305055424986                 ACIDENTE
# 1    201605160250139          INCIDENTE GRAVE
# 2    201805021421302                INCIDENTE
#
#                                      ocorrencia_tipo  \
# 0                              FALHA DO MOTOR EM VOO
# 1  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 2                                          AERÓDROMO
#
#                            ocorrencia_tipo_categoria ocorrencia_tipo_icao  \
# 0                FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 1  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO                 CTOL
# 2                                          AERÓDROMO                 ADRM
#
#    ocorrencia_latitude  ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0              -9.9085              -63.0333         ARIQUEMES            RO
# 1             -11.2644              -61.2589            CACOAL            RO
# ...

# %%
#g
df['ocorrencia_classificacao'].unique()
# Out:
# array(['ACIDENTE', 'INCIDENTE GRAVE', 'INCIDENTE'], dtype=object)

# %%
#h
df['ocorrencia_uf'].value_counts()
# Out:
# SP     1207
# RJ      498
# MG      476
# PR      437
# RS      350
# GO      268
# PA      255
# MT      244
# AM      219
# BA      208
# SC      160
# DF      151
# MS      132
# PE       88
# CE       75
# ES       66
# MA       63
# TO       54
# AC       53
# RR       50
# PI       39
# RO       30
# PB       20
# SE       18
# AL       16
# RN       15
# AP       13
# ***       3
# Name: ocorrencia_uf, dtype: int64

# %%
#i
df['ocorrencia_tipo'].value_counts() / df.shape[0]*100
# Out:
# FALHA DO MOTOR EM VOO                                  13.095238
# ESTOURO DE PNEU                                        11.597542
# FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPONENTE     11.021505
# PERDA DE CONTROLE NO SOLO                               9.447005
# OUTROS                                                  6.720430
#                                                          ...
# CAUSADO POR RICOCHETE                                   0.019201
# RELACIONADO COM SECURITY                                0.019201
# PERDA DA CONSCIÊNCIA                                    0.019201
# ALARME FALSO DE FOGO OU DE SUPERAQUECIMENTO             0.019201
# MANOBRA ABRUPTA                                         0.019201
# Name: ocorrencia_tipo, Length: 63, dtype: float64

# %% [markdown]
# ###Exercício 2

# %%
#a
import pandas as pd

df_bbas = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv", 
                      index_col = 'Date')

# %%
#b
df_bbas.head()
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2019-05-06  49.470001  49.669998  49.180000  49.369999  46.886795   6314800.0
# 2019-05-07  49.080002  49.680000  48.220001  49.490002  47.000763  10846100.0
# 2019-05-08  49.500000  50.840000  49.500000  50.590000  48.045422  14459600.0
# 2019-05-09  50.910000  51.259998  50.119999  51.029999  48.463291  15377500.0
# 2019-05-10  51.099998  51.189999  49.860001  50.160000  47.637051   8975300.0

# %%
#c Quais são os valores da ação para o dia 04 de outubro de 2019?
df_bbas.loc["2019-10-04"]
# Out:
# Open         4.537000e+01
# High         4.560000e+01
# Low          4.462000e+01
# Close        4.560000e+01
# Adj Close    4.444867e+01
# Volume       7.228200e+06
# Name: 2019-10-04, dtype: float64

# %%
#d
df_bbas["Volume"].mean()
# Out:
# 14052947.368421054

# %% [markdown]
# ###Exercício 3

# %%
#a
import pandas as pd

df_bike = pd.read_csv('http://dl.dropboxusercontent.com/s/yyfeoxqw61o3iel/df_rides.csv')

df_bike.head()
# Out:
#   user_gender user_birthdate user_residence   ride_date time_start  time_end  \
# 0           M     1971-06-08            NaN  2018-01-01   06:05:18  06:21:33
# 1           M     1989-02-11             DF  2018-01-01   06:27:01  06:32:17
# 2           M     1968-07-19            NaN  2018-01-01   06:29:33  06:44:57
# 3           M     1991-12-19            NaN  2018-01-01   06:53:53  06:59:45
# 4           M     1969-03-03             DF  2018-01-01   06:58:56  17:40:04
#
#                      station_start  \
# 0                11 - Rodoviária 2
# 1         26 - Ministério da Saude
# 2                11 - Rodoviária 2
# 3  10 - Ministério dos Transportes
# 4                   15 - Brasil 21
#
#                                          station_end  ride_duration  ride_late
# 0                            41 - Instituto de Artes      16.250000        0.0
# 1  28 - CNMP - Conselho Nacional do Ministério Pú...       5.266667        0.0
# ...

# %%
#b
df_bike['user_gender'].isnull().sum()
# Out:
# 396

# %%
#c
df_bike['user_gender'].value_counts()

df_bike_old = df_bike.copy()

df_bike['user_gender'] = df_bike['user_gender'].fillna('M')

# %%
df_bike_old['user_gender'].value_counts()
# Out:
# M    212608
# F     74318
# Name: user_gender, dtype: int64

# %%
df_bike['user_gender'].value_counts()
# Out:
# M    213004
# F     74318
# Name: user_gender, dtype: int64

# %%
#d
import matplotlib.pyplot as plt

df_bike['ride_duration'].plot(kind='box', vert=False);
